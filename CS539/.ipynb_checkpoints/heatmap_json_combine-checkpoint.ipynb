# %%
from keras.preprocessing import image
from tensorflow.python.framework import ops
import keras.backend as K
import tensorflow as tf
import numpy as np
import keras
import cv2
import os

from keras.applications.vgg16 import (VGG16, preprocess_input, decode_predictions)
from keras.applications.resnet50 import (ResNet50, preprocess_input, decode_predictions)

# %%
import pandas as pd
import json

# %%
def normalize(x):
    # utility function to normalize a tensor by its L2 norm
    return x / (K.sqrt(K.mean(K.square(x))) + 1e-5)
def load_image(path):
    img_path = path
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x
def register_gradient():
    if "GuidedBackProp" not in ops._gradient_registry._registry:
        @ops.RegisterGradient("GuidedBackProp")
        def _GuidedBackProp(op, grad):
            dtype = op.inputs[0].dtype
            return grad * tf.cast(grad > 0., dtype) * \
                tf.cast(op.inputs[0] > 0., dtype)
        
#def compile_saliency_function(model, activation_layer='bn5c_branch2b'):
def compile_saliency_function(model, activation_layer):
    input_img = model.input
    layer_dict = dict([(layer.name, layer) for layer in model.layers[1:]])
    layer_output = layer_dict[activation_layer].output
    max_output = K.max(layer_output, axis=3)
    saliency = K.gradients(K.sum(max_output), input_img)[0]
    return K.function([input_img, K.learning_phase()], [saliency])

def deprocess_image(x):
    if np.ndim(x) > 3:
        x = np.squeeze(x)
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    if K.image_dim_ordering() == 'th':
        x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x


def modify_backprop_ResNet50(model, name):
    g = tf.get_default_graph()
    with g.gradient_override_map({'Relu': name}):

        # get layers that have an activation
        layer_dict = [layer for layer in model.layers[1:]
                      if hasattr(layer, 'activation')]

        # replace relu activation
        for layer in layer_dict:
            if layer.activation == keras.activations.relu:
                layer.activation = tf.nn.relu

        # re-instanciate a new model
        new_model = ResNet50(weights='imagenet')
    return new_model

def modify_backprop_VGG16(model, name):
    g = tf.get_default_graph()
    with g.gradient_override_map({'Relu': name}):

        # get layers that have an activation
        layer_dict = [layer for layer in model.layers[1:]
                      if hasattr(layer, 'activation')]

        # replace relu activation
        for layer in layer_dict:
            if layer.activation == keras.activations.relu:
                layer.activation = tf.nn.relu

        # re-instanciate a new model
        new_model = VGG16(weights='imagenet')
    return new_model

# %%
model_res = ResNet50(weights='imagenet')
model_res.summary()
model_vgg = VGG16(weights='imagenet')
model_vgg.summary()
# Out:
# WARNING:tensorflow:From D:\ana_resource\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
pic_folder = "./new_umap_image/"
pic_cam_folder_v = "./img_grad_cam/"
#pic_cam_folder_r = "./img_grad_cam_v/"
list_name = os.listdir(pic_folder)
print("number of image:",len(list_name))

# heat map HSV bounder setting
lower_blue=np.array([110,100,100])#blue
upper_blue=np.array([130,255,255])

lower_green=np.array([40,43,46])#green
upper_green=np.array([110,255,255])

lower_red=np.array([0,43,46])#red
upper_red=np.array([34,255,255])
# Out:
# number of image: 300

# %%
def grad_cam(model, x, category_index, layer_name, model2, category_index2, layer_name2):
    """
    Args:
       model: model
       x: image input
       category_index: category index
       layer_name: last convolution layer name
    """
    # get category loss
    class_output = model.output[:, category_index]
    class_output2 = model2.output[:, category_index2]

    # layer output
    convolution_output = model.get_layer(layer_name).output
    convolution_output2 = model2.get_layer(layer_name2).output
    
    # get gradients
    grads = K.gradients(class_output, convolution_output)[0]
    grads2 = K.gradients(class_output2, convolution_output2)[0]
    
    # get convolution output and gradients for input
    gradient_function = K.function([model.input], [convolution_output, grads])
    output, grads_val = gradient_function([x])
    output, grads_val = output[0], grads_val[0]
    
    gradient_function2 = K.function([model2.input], [convolution_output2, grads2])
    output2, grads_val2 = gradient_function2([x])
    output2, grads_val2 = output2[0], grads_val2[0]
    
    # avg
    weights = np.mean(grads_val, axis=(0, 1))
    cam = np.dot(output, weights)
    
    weights2 = np.mean(grads_val2, axis=(0, 1))
    cam2 = np.dot(output2, weights2)
    
    # create heat map
    # model 1 Vgg16
    cam = cv2.resize(cam, (x.shape[1], x.shape[2]), cv2.INTER_LINEAR)
    cam = np.maximum(cam, 0)
    heatmap = cam / np.max(cam)
    heatmap = np.where(heatmap > 0.35, heatmap, 0)
    cam = cv2.applyColorMap(np.uint8(255 * heatmap), cv2.COLORMAP_JET)
    hsv=cv2.cvtColor(cam,cv2.COLOR_BGR2HSV)
    red_mask=cv2.inRange(hsv,lower_red,upper_red)
    red=cv2.bitwise_and(cam,cam,mask=red_mask)
    # model 2 ResNet
    cam2 = cv2.resize(cam2, (x.shape[1], x.shape[2]), cv2.INTER_LINEAR)
    cam2 = np.maximum(cam2, 0)
    heatmap2 = cam2 / np.max(cam2)
    heatmap2 = np.where(heatmap2 > 0.35, heatmap2, 0)
    cam2 = cv2.applyColorMap(np.uint8(255 * heatmap2), cv2.COLORMAP_WINTER)
    hsv2=cv2.cvtColor(cam2,cv2.COLOR_BGR2HSV)
    green_mask2=cv2.inRange(hsv2,lower_green,upper_green)
    green2=cv2.bitwise_and(cam2,cam2,mask=green_mask2)

        
    # Return to BGR [0..255] from the preprocessed image
    image_rgb = x[0, :]
    image_rgb -= np.min(image_rgb)
    image_rgb = np.minimum(image_rgb, 255)
  
    # model_1
    cam_net1 = np.float32(red) + np.float32(image_rgb)
    # model_2
    cam_net2 = np.float32(green2) + np.float32(image_rgb)
    # combine model_1 and model_2
    cam_net3 = np.float32(red) + np.float32(green2) + np.float32(image_rgb) 

    # color repair
    cam_net1 = 255 * cam_net1 / np.max(cam_net1)
    cam_net2 = 255 * cam_net2 / np.max(cam_net2)
    cam_net3 = 255 * cam_net3 / np.max(cam_net3)
    
    #print(cam)
    return np.uint8(cam_net1), np.uint8(cam_net2), np.uint8(cam_net3), heatmap, heatmap2

# %%
##############################
# test function
##############################



file_name = list_name[1]
img = load_image(pic_folder + file_name)

# print function
# vgg 16 predictions
predictions_v = model_vgg.predict(img)
top_1_v = decode_predictions(predictions_v)[0][0]
# res 50 predictions
predictions_r = model_res.predict(img)
top_1_r = decode_predictions(predictions_r)[0][0]
print('Predicted class:')
print("pic_ID:", file_name)
print("vgg net :",'%s (%s) with probability %.2f' % (top_1_v[1], top_1_v[0], top_1_v[2]))
print("res net :",'%s (%s) with probability %.2f' % (top_1_r[1], top_1_r[0], top_1_r[2]))


predict_lable_model_1 = []
predict_lable_model_2 = []
prop_model_1 = []
prop_model_2 = []
predict_lable_model_1.append(top_1_v[1])
predict_lable_model_2.append(top_1_r[1])
prop_model_1.append(top_1_v[2])
prop_model_2.append(top_1_r[2])


predicted_class_v = np.argmax(predictions_v)
predicted_class_r = np.argmax(predictions_r)
cam_image1,cam_image2,cam_image3, heat_map_v, heat_map_r = grad_cam(model_vgg, img, predicted_class_v, "block5_pool",
                                              model_res, predicted_class_r, "bn5c_branch2b")
img_file = image.load_img(pic_folder + file_name)
img_file = image.img_to_array(img_file)


# resize for cam_image
cam_image1 = cv2.resize(cam_image1, (img_file.shape[1], img_file.shape[0]), cv2.INTER_LINEAR)
cam_image1 = cam_image1.astype('float32')
cam_image2 = cv2.resize(cam_image2, (img_file.shape[1], img_file.shape[0]), cv2.INTER_LINEAR)
cam_image2 = cam_image2.astype('float32')
cam_image3 = cv2.resize(cam_image3, (img_file.shape[1], img_file.shape[0]), cv2.INTER_LINEAR)
cam_image3 = cam_image3.astype('float32')


name_str = file_name.split('.')
name_heatmap_model_1 = name_str[0] + "_1"+ "." + name_str[1]
name_heatmap_model_2 = name_str[0] + "_2"+ "." + name_str[1]
name_heatmap_model_3 = name_str[0] + "_3"+ "." + name_str[1]
cv2.imwrite(pic_cam_folder_v + name_heatmap_model_1, cam_image1)
cv2.imwrite(pic_cam_folder_v + name_heatmap_model_2, cam_image2)
cv2.imwrite(pic_cam_folder_v + name_heatmap_model_3, cam_image3)
print("save heatmap_model_1 => ",name_heatmap_model_1)
print("save heatmap_model_2 => ",name_heatmap_model_2)
print("save heatmap_combine => ",name_heatmap_model_3)
print("-------------------------------------------------------------")
# Out:
# Predicted class:
# pic_ID: n01685808_123.JPEG
# vgg net : whiptail (n01685808) with probability 0.79
# res net : alligator_lizard (n01689811) with probability 0.83
# WARNING:tensorflow:From D:\ana_resource\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# save heatmap_model_1 =>  n01685808_123_1.JPEG
# save heatmap_model_2 =>  n01685808_123_2.JPEG
# save heatmap_combine =>  n01685808_123_3.JPEG
# -------------------------------------------------------------

# %%
print(predicted_class_v)
# Out:
# 41

# %%
test_sort = []


predict_lable_model_1 = []
predict_lable_model_2 = []
prop_model_1 = []
prop_model_2 = []

model_1_heatmap_ID = []
model_2_heatmap_ID = []
combine_heatmap_ID = []

for i, file_name in enumerate(list_name):
    img = load_image(pic_folder + file_name)
    # print function
    # vgg 16 predictions
    predictions_v = model_vgg.predict(img)
    top_1_v = decode_predictions(predictions_v)[0][0]
    # res 50 predictions
    predictions_r = model_res.predict(img)
    top_1_r = decode_predictions(predictions_r)[0][0]
    print("Index:",i)
    print("File name:",file_name)
    print('Predicted class:')
    print("vgg net :",'%s (%s) with probability %.2f' % (top_1_v[1], top_1_v[0], top_1_v[2]))
    print("res net :",'%s (%s) with probability %.2f' % (top_1_r[1], top_1_r[0], top_1_r[2]))
    print("-------------------------------------------------------------")
    
    
    
    predict_lable_model_1.append(top_1_v[1])
    predict_lable_model_2.append(top_1_r[1])
    prop_model_1.append(str(top_1_v[2]))
    prop_model_2.append(str(top_1_r[2]))
    

    predicted_class_v = np.argmax(predictions_v)
    predicted_class_r = np.argmax(predictions_r)
    cam_image1,cam_image2,cam_image3, heat_map_v, heat_map_r = grad_cam(model_vgg, img, predicted_class_v, "block5_pool",
                                              model_res, predicted_class_r, "bn5c_branch2b")    
    img_file = image.load_img(pic_folder + list_name[i])
    img_file = image.img_to_array(img_file)
    
    # resize for cam_image
    cam_image1 = cv2.resize(cam_image1, (img_file.shape[1], img_file.shape[0]), cv2.INTER_LINEAR)
    cam_image1 = cam_image1.astype('float32')
    cam_image2 = cv2.resize(cam_image2, (img_file.shape[1], img_file.shape[0]), cv2.INTER_LINEAR)
    cam_image2 = cam_image2.astype('float32')
    cam_image3 = cv2.resize(cam_image3, (img_file.shape[1], img_file.shape[0]), cv2.INTER_LINEAR)
    cam_image3 = cam_image3.astype('float32')

    
    name_str = file_name.split('.')
    name_heatmap_model_1 = name_str[0] + "_1"+ "." + name_str[1]
    name_heatmap_model_2 = name_str[0] + "_2"+ "." + name_str[1]
    name_heatmap_model_3 = name_str[0] + "_3"+ "." + name_str[1]
    
    # create json data
    test_sort.append(name_str[0])
    model_1_heatmap_ID.append(name_str[0] + "_1")
    model_2_heatmap_ID.append(name_str[0] + "_2")
    combine_heatmap_ID.append(name_str[0] + "_3")
    
    cv2.imwrite(pic_cam_folder_v + name_heatmap_model_1, cam_image1)
    cv2.imwrite(pic_cam_folder_v + name_heatmap_model_2, cam_image2)
    cv2.imwrite(pic_cam_folder_v + name_heatmap_model_3, cam_image3)
    print("save heatmap_model_1 => ",name_heatmap_model_1)
    print("save heatmap_model_2 => ",name_heatmap_model_2)
    print("save heatmap_combine => ",name_heatmap_model_3)
    print("-------------------------------------------------------------")
# Out:
# Index: 0
# File name: n01685808_102.JPEG
# Predicted class:
# vgg net : alligator_lizard (n01689811) with probability 0.62
# res net : whiptail (n01685808) with probability 0.85
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_102_1.JPEG
# save heatmap_model_2 =>  n01685808_102_2.JPEG
# save heatmap_combine =>  n01685808_102_3.JPEG
# -------------------------------------------------------------
# Index: 1
# File name: n01685808_123.JPEG
# Predicted class:
# vgg net : whiptail (n01685808) with probability 0.79
# res net : alligator_lizard (n01689811) with probability 0.83
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_123_1.JPEG
# save heatmap_model_2 =>  n01685808_123_2.JPEG
# save heatmap_combine =>  n01685808_123_3.JPEG
# -------------------------------------------------------------
# Index: 2
# File name: n01685808_147.JPEG
# Predicted class:
# vgg net : whiptail (n01685808) with probability 0.88
# res net : whiptail (n01685808) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_147_1.JPEG
# save heatmap_model_2 =>  n01685808_147_2.JPEG
# save heatmap_combine =>  n01685808_147_3.JPEG
# -------------------------------------------------------------
# Index: 3
# File name: n01685808_165.JPEG
# Predicted class:
# vgg net : whiptail (n01685808) with probability 0.81
# res net : whiptail (n01685808) with probability 0.90
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_165_1.JPEG
# save heatmap_model_2 =>  n01685808_165_2.JPEG
# save heatmap_combine =>  n01685808_165_3.JPEG
# -------------------------------------------------------------
# Index: 4
# File name: n01685808_203.JPEG
# Predicted class:
# vgg net : whiptail (n01685808) with probability 0.59
# res net : agama (n01687978) with probability 0.60
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_203_1.JPEG
# save heatmap_model_2 =>  n01685808_203_2.JPEG
# save heatmap_combine =>  n01685808_203_3.JPEG
# -------------------------------------------------------------
# Index: 5
# File name: n01685808_214.JPEG
# Predicted class:
# vgg net : whiptail (n01685808) with probability 0.81
# res net : whiptail (n01685808) with probability 0.97
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_214_1.JPEG
# save heatmap_model_2 =>  n01685808_214_2.JPEG
# save heatmap_combine =>  n01685808_214_3.JPEG
# -------------------------------------------------------------
# Index: 6
# File name: n01685808_216.JPEG
# Predicted class:
# vgg net : garter_snake (n01735189) with probability 0.46
# res net : whiptail (n01685808) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_216_1.JPEG
# save heatmap_model_2 =>  n01685808_216_2.JPEG
# save heatmap_combine =>  n01685808_216_3.JPEG
# -------------------------------------------------------------
# Index: 7
# File name: n01685808_224.JPEG
# Predicted class:
# vgg net : alligator_lizard (n01689811) with probability 0.42
# res net : alligator_lizard (n01689811) with probability 0.39
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_224_1.JPEG
# save heatmap_model_2 =>  n01685808_224_2.JPEG
# save heatmap_combine =>  n01685808_224_3.JPEG
# -------------------------------------------------------------
# Index: 8
# File name: n01685808_58.JPEG
# Predicted class:
# vgg net : alligator_lizard (n01689811) with probability 0.66
# res net : whiptail (n01685808) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_58_1.JPEG
# save heatmap_model_2 =>  n01685808_58_2.JPEG
# save heatmap_combine =>  n01685808_58_3.JPEG
# -------------------------------------------------------------
# Index: 9
# File name: n01685808_81.JPEG
# Predicted class:
# vgg net : whiptail (n01685808) with probability 0.80
# res net : banded_gecko (n01675722) with probability 0.37
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01685808_81_1.JPEG
# save heatmap_model_2 =>  n01685808_81_2.JPEG
# save heatmap_combine =>  n01685808_81_3.JPEG
# -------------------------------------------------------------
# Index: 10
# File name: n01729322_106.JPEG
# Predicted class:
# vgg net : hognose_snake (n01729322) with probability 0.56
# res net : hognose_snake (n01729322) with probability 0.75
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_106_1.JPEG
# save heatmap_model_2 =>  n01729322_106_2.JPEG
# save heatmap_combine =>  n01729322_106_3.JPEG
# -------------------------------------------------------------
# Index: 11
# File name: n01729322_141.JPEG
# Predicted class:
# vgg net : hognose_snake (n01729322) with probability 0.95
# res net : hognose_snake (n01729322) with probability 0.73
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_141_1.JPEG
# save heatmap_model_2 =>  n01729322_141_2.JPEG
# save heatmap_combine =>  n01729322_141_3.JPEG
# -------------------------------------------------------------
# Index: 12
# File name: n01729322_151.JPEG
# Predicted class:
# vgg net : hognose_snake (n01729322) with probability 0.81
# res net : hognose_snake (n01729322) with probability 0.87
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_151_1.JPEG
# save heatmap_model_2 =>  n01729322_151_2.JPEG
# save heatmap_combine =>  n01729322_151_3.JPEG
# -------------------------------------------------------------
# Index: 13
# File name: n01729322_17.JPEG
# Predicted class:
# vgg net : horned_viper (n01753488) with probability 0.81
# res net : horned_viper (n01753488) with probability 0.91
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_17_1.JPEG
# save heatmap_model_2 =>  n01729322_17_2.JPEG
# save heatmap_combine =>  n01729322_17_3.JPEG
# -------------------------------------------------------------
# Index: 14
# File name: n01729322_185.JPEG
# Predicted class:
# vgg net : water_snake (n01737021) with probability 0.34
# res net : diamondback (n01755581) with probability 0.38
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_185_1.JPEG
# save heatmap_model_2 =>  n01729322_185_2.JPEG
# save heatmap_combine =>  n01729322_185_3.JPEG
# -------------------------------------------------------------
# Index: 15
# File name: n01729322_219.JPEG
# Predicted class:
# vgg net : water_snake (n01737021) with probability 0.62
# res net : water_snake (n01737021) with probability 0.56
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_219_1.JPEG
# save heatmap_model_2 =>  n01729322_219_2.JPEG
# save heatmap_combine =>  n01729322_219_3.JPEG
# -------------------------------------------------------------
# Index: 16
# File name: n01729322_289.JPEG
# Predicted class:
# vgg net : night_snake (n01740131) with probability 0.33
# res net : ringneck_snake (n01728920) with probability 0.27
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_289_1.JPEG
# save heatmap_model_2 =>  n01729322_289_2.JPEG
# save heatmap_combine =>  n01729322_289_3.JPEG
# -------------------------------------------------------------
# Index: 17
# File name: n01729322_307.JPEG
# Predicted class:
# vgg net : hognose_snake (n01729322) with probability 0.68
# res net : hognose_snake (n01729322) with probability 0.96
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_307_1.JPEG
# save heatmap_model_2 =>  n01729322_307_2.JPEG
# save heatmap_combine =>  n01729322_307_3.JPEG
# -------------------------------------------------------------
# Index: 18
# File name: n01729322_322.JPEG
# Predicted class:
# vgg net : horned_viper (n01753488) with probability 0.29
# res net : horned_viper (n01753488) with probability 0.73
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_322_1.JPEG
# save heatmap_model_2 =>  n01729322_322_2.JPEG
# save heatmap_combine =>  n01729322_322_3.JPEG
# -------------------------------------------------------------
# Index: 19
# File name: n01729322_38.JPEG
# Predicted class:
# vgg net : hognose_snake (n01729322) with probability 0.31
# res net : hognose_snake (n01729322) with probability 0.92
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01729322_38_1.JPEG
# save heatmap_model_2 =>  n01729322_38_2.JPEG
# save heatmap_combine =>  n01729322_38_3.JPEG
# -------------------------------------------------------------
# Index: 20
# File name: n01843065_105.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 1.00
# res net : jacamar (n01843065) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_105_1.JPEG
# save heatmap_model_2 =>  n01843065_105_2.JPEG
# save heatmap_combine =>  n01843065_105_3.JPEG
# -------------------------------------------------------------
# Index: 21
# File name: n01843065_115.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 0.97
# res net : jacamar (n01843065) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_115_1.JPEG
# save heatmap_model_2 =>  n01843065_115_2.JPEG
# save heatmap_combine =>  n01843065_115_3.JPEG
# -------------------------------------------------------------
# Index: 22
# File name: n01843065_117.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 1.00
# res net : jacamar (n01843065) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_117_1.JPEG
# save heatmap_model_2 =>  n01843065_117_2.JPEG
# save heatmap_combine =>  n01843065_117_3.JPEG
# -------------------------------------------------------------
# Index: 23
# File name: n01843065_16.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 0.90
# res net : jacamar (n01843065) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_16_1.JPEG
# save heatmap_model_2 =>  n01843065_16_2.JPEG
# save heatmap_combine =>  n01843065_16_3.JPEG
# -------------------------------------------------------------
# Index: 24
# File name: n01843065_19.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 0.97
# res net : jacamar (n01843065) with probability 0.94
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_19_1.JPEG
# save heatmap_model_2 =>  n01843065_19_2.JPEG
# save heatmap_combine =>  n01843065_19_3.JPEG
# -------------------------------------------------------------
# Index: 25
# File name: n01843065_3.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 0.99
# res net : jacamar (n01843065) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_3_1.JPEG
# save heatmap_model_2 =>  n01843065_3_2.JPEG
# save heatmap_combine =>  n01843065_3_3.JPEG
# -------------------------------------------------------------
# Index: 26
# File name: n01843065_36.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 1.00
# res net : jacamar (n01843065) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_36_1.JPEG
# save heatmap_model_2 =>  n01843065_36_2.JPEG
# save heatmap_combine =>  n01843065_36_3.JPEG
# -------------------------------------------------------------
# Index: 27
# File name: n01843065_43.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 0.98
# res net : jacamar (n01843065) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_43_1.JPEG
# save heatmap_model_2 =>  n01843065_43_2.JPEG
# save heatmap_combine =>  n01843065_43_3.JPEG
# -------------------------------------------------------------
# Index: 28
# File name: n01843065_84.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 1.00
# res net : jacamar (n01843065) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_84_1.JPEG
# save heatmap_model_2 =>  n01843065_84_2.JPEG
# save heatmap_combine =>  n01843065_84_3.JPEG
# -------------------------------------------------------------
# Index: 29
# File name: n01843065_93.JPEG
# Predicted class:
# vgg net : jacamar (n01843065) with probability 1.00
# res net : jacamar (n01843065) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01843065_93_1.JPEG
# save heatmap_model_2 =>  n01843065_93_2.JPEG
# save heatmap_combine =>  n01843065_93_3.JPEG
# -------------------------------------------------------------
# Index: 30
# File name: n01984695_1012.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 1.00
# res net : spiny_lobster (n01984695) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_1012_1.JPEG
# save heatmap_model_2 =>  n01984695_1012_2.JPEG
# save heatmap_combine =>  n01984695_1012_3.JPEG
# -------------------------------------------------------------
# Index: 31
# File name: n01984695_1023.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 0.71
# res net : hermit_crab (n01986214) with probability 0.40
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_1023_1.JPEG
# save heatmap_model_2 =>  n01984695_1023_2.JPEG
# save heatmap_combine =>  n01984695_1023_3.JPEG
# -------------------------------------------------------------
# Index: 32
# File name: n01984695_114.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 0.96
# res net : spiny_lobster (n01984695) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_114_1.JPEG
# save heatmap_model_2 =>  n01984695_114_2.JPEG
# save heatmap_combine =>  n01984695_114_3.JPEG
# -------------------------------------------------------------
# Index: 33
# File name: n01984695_380.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 0.99
# res net : spiny_lobster (n01984695) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_380_1.JPEG
# save heatmap_model_2 =>  n01984695_380_2.JPEG
# save heatmap_combine =>  n01984695_380_3.JPEG
# -------------------------------------------------------------
# Index: 34
# File name: n01984695_403.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 0.43
# res net : spiny_lobster (n01984695) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_403_1.JPEG
# save heatmap_model_2 =>  n01984695_403_2.JPEG
# save heatmap_combine =>  n01984695_403_3.JPEG
# -------------------------------------------------------------
# Index: 35
# File name: n01984695_546.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 0.88
# res net : spiny_lobster (n01984695) with probability 0.51
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_546_1.JPEG
# save heatmap_model_2 =>  n01984695_546_2.JPEG
# save heatmap_combine =>  n01984695_546_3.JPEG
# -------------------------------------------------------------
# Index: 36
# File name: n01984695_659.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 0.76
# res net : spiny_lobster (n01984695) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_659_1.JPEG
# save heatmap_model_2 =>  n01984695_659_2.JPEG
# save heatmap_combine =>  n01984695_659_3.JPEG
# -------------------------------------------------------------
# Index: 37
# File name: n01984695_745.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 1.00
# res net : spiny_lobster (n01984695) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_745_1.JPEG
# save heatmap_model_2 =>  n01984695_745_2.JPEG
# save heatmap_combine =>  n01984695_745_3.JPEG
# -------------------------------------------------------------
# Index: 38
# File name: n01984695_840.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 1.00
# res net : spiny_lobster (n01984695) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_840_1.JPEG
# save heatmap_model_2 =>  n01984695_840_2.JPEG
# save heatmap_combine =>  n01984695_840_3.JPEG
# -------------------------------------------------------------
# Index: 39
# File name: n01984695_86.JPEG
# Predicted class:
# vgg net : spiny_lobster (n01984695) with probability 0.63
# res net : spiny_lobster (n01984695) with probability 0.79
# -------------------------------------------------------------
# save heatmap_model_1 =>  n01984695_86_1.JPEG
# save heatmap_model_2 =>  n01984695_86_2.JPEG
# save heatmap_combine =>  n01984695_86_3.JPEG
# -------------------------------------------------------------
# Index: 40
# File name: n02025239_10.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 0.99
# res net : ruddy_turnstone (n02025239) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_10_1.JPEG
# save heatmap_model_2 =>  n02025239_10_2.JPEG
# save heatmap_combine =>  n02025239_10_3.JPEG
# -------------------------------------------------------------
# Index: 41
# File name: n02025239_123.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 0.80
# res net : ruddy_turnstone (n02025239) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_123_1.JPEG
# save heatmap_model_2 =>  n02025239_123_2.JPEG
# save heatmap_combine =>  n02025239_123_3.JPEG
# -------------------------------------------------------------
# Index: 42
# File name: n02025239_15.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 0.99
# res net : ruddy_turnstone (n02025239) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_15_1.JPEG
# save heatmap_model_2 =>  n02025239_15_2.JPEG
# save heatmap_combine =>  n02025239_15_3.JPEG
# -------------------------------------------------------------
# Index: 43
# File name: n02025239_152.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 1.00
# res net : ruddy_turnstone (n02025239) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_152_1.JPEG
# save heatmap_model_2 =>  n02025239_152_2.JPEG
# save heatmap_combine =>  n02025239_152_3.JPEG
# -------------------------------------------------------------
# Index: 44
# File name: n02025239_19.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 1.00
# res net : ruddy_turnstone (n02025239) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_19_1.JPEG
# save heatmap_model_2 =>  n02025239_19_2.JPEG
# save heatmap_combine =>  n02025239_19_3.JPEG
# -------------------------------------------------------------
# Index: 45
# File name: n02025239_45.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 1.00
# res net : ruddy_turnstone (n02025239) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_45_1.JPEG
# save heatmap_model_2 =>  n02025239_45_2.JPEG
# save heatmap_combine =>  n02025239_45_3.JPEG
# -------------------------------------------------------------
# Index: 46
# File name: n02025239_58.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 0.81
# res net : ruddy_turnstone (n02025239) with probability 0.92
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_58_1.JPEG
# save heatmap_model_2 =>  n02025239_58_2.JPEG
# save heatmap_combine =>  n02025239_58_3.JPEG
# -------------------------------------------------------------
# Index: 47
# File name: n02025239_73.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 1.00
# res net : ruddy_turnstone (n02025239) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_73_1.JPEG
# save heatmap_model_2 =>  n02025239_73_2.JPEG
# save heatmap_combine =>  n02025239_73_3.JPEG
# -------------------------------------------------------------
# Index: 48
# File name: n02025239_82.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 1.00
# res net : ruddy_turnstone (n02025239) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_82_1.JPEG
# save heatmap_model_2 =>  n02025239_82_2.JPEG
# save heatmap_combine =>  n02025239_82_3.JPEG
# -------------------------------------------------------------
# Index: 49
# File name: n02025239_9.JPEG
# Predicted class:
# vgg net : ruddy_turnstone (n02025239) with probability 1.00
# res net : ruddy_turnstone (n02025239) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02025239_9_1.JPEG
# save heatmap_model_2 =>  n02025239_9_2.JPEG
# save heatmap_combine =>  n02025239_9_3.JPEG
# -------------------------------------------------------------
# Index: 50
# File name: n02086240_110.JPEG
# Predicted class:
# vgg net : Brabancon_griffon (n02112706) with probability 0.70
# res net : Shih-Tzu (n02086240) with probability 0.31
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_110_1.JPEG
# save heatmap_model_2 =>  n02086240_110_2.JPEG
# save heatmap_combine =>  n02086240_110_3.JPEG
# -------------------------------------------------------------
# Index: 51
# File name: n02086240_126.JPEG
# Predicted class:
# vgg net : Maltese_dog (n02085936) with probability 0.63
# res net : Shih-Tzu (n02086240) with probability 0.85
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_126_1.JPEG
# save heatmap_model_2 =>  n02086240_126_2.JPEG
# save heatmap_combine =>  n02086240_126_3.JPEG
# -------------------------------------------------------------
# Index: 52
# File name: n02086240_30.JPEG
# Predicted class:
# vgg net : soft-coated_wheaten_terrier (n02098105) with probability 0.28
# res net : Lhasa (n02098413) with probability 0.25
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_30_1.JPEG
# save heatmap_model_2 =>  n02086240_30_2.JPEG
# save heatmap_combine =>  n02086240_30_3.JPEG
# -------------------------------------------------------------
# Index: 53
# File name: n02086240_32.JPEG
# Predicted class:
# vgg net : Lhasa (n02098413) with probability 0.77
# res net : Shih-Tzu (n02086240) with probability 0.85
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_32_1.JPEG
# save heatmap_model_2 =>  n02086240_32_2.JPEG
# save heatmap_combine =>  n02086240_32_3.JPEG
# -------------------------------------------------------------
# Index: 54
# File name: n02086240_34.JPEG
# Predicted class:
# vgg net : Shih-Tzu (n02086240) with probability 0.85
# res net : Shih-Tzu (n02086240) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_34_1.JPEG
# save heatmap_model_2 =>  n02086240_34_2.JPEG
# save heatmap_combine =>  n02086240_34_3.JPEG
# -------------------------------------------------------------
# Index: 55
# File name: n02086240_46.JPEG
# Predicted class:
# vgg net : Shih-Tzu (n02086240) with probability 0.57
# res net : Shih-Tzu (n02086240) with probability 0.88
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_46_1.JPEG
# save heatmap_model_2 =>  n02086240_46_2.JPEG
# save heatmap_combine =>  n02086240_46_3.JPEG
# -------------------------------------------------------------
# Index: 56
# File name: n02086240_61.JPEG
# Predicted class:
# vgg net : Shih-Tzu (n02086240) with probability 0.92
# res net : Shih-Tzu (n02086240) with probability 0.96
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_61_1.JPEG
# save heatmap_model_2 =>  n02086240_61_2.JPEG
# save heatmap_combine =>  n02086240_61_3.JPEG
# -------------------------------------------------------------
# Index: 57
# File name: n02086240_83.JPEG
# Predicted class:
# vgg net : Lhasa (n02098413) with probability 0.69
# res net : Lhasa (n02098413) with probability 0.72
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_83_1.JPEG
# save heatmap_model_2 =>  n02086240_83_2.JPEG
# save heatmap_combine =>  n02086240_83_3.JPEG
# -------------------------------------------------------------
# Index: 58
# File name: n02086240_89.JPEG
# Predicted class:
# vgg net : affenpinscher (n02110627) with probability 0.51
# res net : affenpinscher (n02110627) with probability 0.82
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_89_1.JPEG
# save heatmap_model_2 =>  n02086240_89_2.JPEG
# save heatmap_combine =>  n02086240_89_3.JPEG
# -------------------------------------------------------------
# Index: 59
# File name: n02086240_9.JPEG
# Predicted class:
# vgg net : Shih-Tzu (n02086240) with probability 0.73
# res net : Shih-Tzu (n02086240) with probability 0.97
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02086240_9_1.JPEG
# save heatmap_model_2 =>  n02086240_9_2.JPEG
# save heatmap_combine =>  n02086240_9_3.JPEG
# -------------------------------------------------------------
# Index: 60
# File name: n02089078_111.JPEG
# Predicted class:
# vgg net : Gordon_setter (n02101006) with probability 0.77
# res net : black-and-tan_coonhound (n02089078) with probability 0.75
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_111_1.JPEG
# save heatmap_model_2 =>  n02089078_111_2.JPEG
# save heatmap_combine =>  n02089078_111_3.JPEG
# -------------------------------------------------------------
# Index: 61
# File name: n02089078_117.JPEG
# Predicted class:
# vgg net : black-and-tan_coonhound (n02089078) with probability 0.80
# res net : black-and-tan_coonhound (n02089078) with probability 0.86
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_117_1.JPEG
# save heatmap_model_2 =>  n02089078_117_2.JPEG
# save heatmap_combine =>  n02089078_117_3.JPEG
# -------------------------------------------------------------
# Index: 62
# File name: n02089078_19.JPEG
# Predicted class:
# vgg net : Gordon_setter (n02101006) with probability 0.95
# res net : black-and-tan_coonhound (n02089078) with probability 0.94
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_19_1.JPEG
# save heatmap_model_2 =>  n02089078_19_2.JPEG
# save heatmap_combine =>  n02089078_19_3.JPEG
# -------------------------------------------------------------
# Index: 63
# File name: n02089078_4.JPEG
# Predicted class:
# vgg net : bloodhound (n02088466) with probability 0.63
# res net : bloodhound (n02088466) with probability 0.85
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_4_1.JPEG
# save heatmap_model_2 =>  n02089078_4_2.JPEG
# save heatmap_combine =>  n02089078_4_3.JPEG
# -------------------------------------------------------------
# Index: 64
# File name: n02089078_43.JPEG
# Predicted class:
# vgg net : boathouse (n02859443) with probability 0.37
# res net : black-and-tan_coonhound (n02089078) with probability 0.56
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_43_1.JPEG
# save heatmap_model_2 =>  n02089078_43_2.JPEG
# save heatmap_combine =>  n02089078_43_3.JPEG
# -------------------------------------------------------------
# Index: 65
# File name: n02089078_45.JPEG
# Predicted class:
# vgg net : Gordon_setter (n02101006) with probability 0.99
# res net : Gordon_setter (n02101006) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_45_1.JPEG
# save heatmap_model_2 =>  n02089078_45_2.JPEG
# save heatmap_combine =>  n02089078_45_3.JPEG
# -------------------------------------------------------------
# Index: 66
# File name: n02089078_52.JPEG
# Predicted class:
# vgg net : black-and-tan_coonhound (n02089078) with probability 0.75
# res net : bloodhound (n02088466) with probability 0.51
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_52_1.JPEG
# save heatmap_model_2 =>  n02089078_52_2.JPEG
# save heatmap_combine =>  n02089078_52_3.JPEG
# -------------------------------------------------------------
# Index: 67
# File name: n02089078_55.JPEG
# Predicted class:
# vgg net : black-and-tan_coonhound (n02089078) with probability 0.87
# res net : black-and-tan_coonhound (n02089078) with probability 0.94
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_55_1.JPEG
# save heatmap_model_2 =>  n02089078_55_2.JPEG
# save heatmap_combine =>  n02089078_55_3.JPEG
# -------------------------------------------------------------
# Index: 68
# File name: n02089078_71.JPEG
# Predicted class:
# vgg net : black-and-tan_coonhound (n02089078) with probability 0.69
# res net : black-and-tan_coonhound (n02089078) with probability 0.79
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_71_1.JPEG
# save heatmap_model_2 =>  n02089078_71_2.JPEG
# save heatmap_combine =>  n02089078_71_3.JPEG
# -------------------------------------------------------------
# Index: 69
# File name: n02089078_80.JPEG
# Predicted class:
# vgg net : black-and-tan_coonhound (n02089078) with probability 0.93
# res net : black-and-tan_coonhound (n02089078) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089078_80_1.JPEG
# save heatmap_model_2 =>  n02089078_80_2.JPEG
# save heatmap_combine =>  n02089078_80_3.JPEG
# -------------------------------------------------------------
# Index: 70
# File name: n02089867_126.JPEG
# Predicted class:
# vgg net : Walker_hound (n02089867) with probability 0.51
# res net : basset (n02088238) with probability 0.62
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_126_1.JPEG
# save heatmap_model_2 =>  n02089867_126_2.JPEG
# save heatmap_combine =>  n02089867_126_3.JPEG
# -------------------------------------------------------------
# Index: 71
# File name: n02089867_136.JPEG
# Predicted class:
# vgg net : basset (n02088238) with probability 0.75
# res net : basset (n02088238) with probability 0.48
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_136_1.JPEG
# save heatmap_model_2 =>  n02089867_136_2.JPEG
# save heatmap_combine =>  n02089867_136_3.JPEG
# -------------------------------------------------------------
# Index: 72
# File name: n02089867_20.JPEG
# Predicted class:
# vgg net : bluetick (n02088632) with probability 0.43
# res net : Walker_hound (n02089867) with probability 0.51
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_20_1.JPEG
# save heatmap_model_2 =>  n02089867_20_2.JPEG
# save heatmap_combine =>  n02089867_20_3.JPEG
# -------------------------------------------------------------
# Index: 73
# File name: n02089867_24.JPEG
# Predicted class:
# vgg net : Walker_hound (n02089867) with probability 0.29
# res net : beagle (n02088364) with probability 0.36
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_24_1.JPEG
# save heatmap_model_2 =>  n02089867_24_2.JPEG
# save heatmap_combine =>  n02089867_24_3.JPEG
# -------------------------------------------------------------
# Index: 74
# File name: n02089867_31.JPEG
# Predicted class:
# vgg net : Walker_hound (n02089867) with probability 0.52
# res net : Walker_hound (n02089867) with probability 0.74
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_31_1.JPEG
# save heatmap_model_2 =>  n02089867_31_2.JPEG
# save heatmap_combine =>  n02089867_31_3.JPEG
# -------------------------------------------------------------
# Index: 75
# File name: n02089867_42.JPEG
# Predicted class:
# vgg net : Walker_hound (n02089867) with probability 0.56
# res net : Walker_hound (n02089867) with probability 0.93
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_42_1.JPEG
# save heatmap_model_2 =>  n02089867_42_2.JPEG
# save heatmap_combine =>  n02089867_42_3.JPEG
# -------------------------------------------------------------
# Index: 76
# File name: n02089867_55.JPEG
# Predicted class:
# vgg net : Walker_hound (n02089867) with probability 0.74
# res net : Walker_hound (n02089867) with probability 0.89
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_55_1.JPEG
# save heatmap_model_2 =>  n02089867_55_2.JPEG
# save heatmap_combine =>  n02089867_55_3.JPEG
# -------------------------------------------------------------
# Index: 77
# File name: n02089867_69.JPEG
# Predicted class:
# vgg net : Walker_hound (n02089867) with probability 0.86
# res net : basset (n02088238) with probability 0.78
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_69_1.JPEG
# save heatmap_model_2 =>  n02089867_69_2.JPEG
# save heatmap_combine =>  n02089867_69_3.JPEG
# -------------------------------------------------------------
# Index: 78
# File name: n02089867_90.JPEG
# Predicted class:
# vgg net : Walker_hound (n02089867) with probability 0.69
# res net : Walker_hound (n02089867) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_90_1.JPEG
# save heatmap_model_2 =>  n02089867_90_2.JPEG
# save heatmap_combine =>  n02089867_90_3.JPEG
# -------------------------------------------------------------
# Index: 79
# File name: n02089867_91.JPEG
# Predicted class:
# vgg net : beagle (n02088364) with probability 0.36
# res net : Walker_hound (n02089867) with probability 0.44
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02089867_91_1.JPEG
# save heatmap_model_2 =>  n02089867_91_2.JPEG
# save heatmap_combine =>  n02089867_91_3.JPEG
# -------------------------------------------------------------
# Index: 80
# File name: n02090379_13.JPEG
# Predicted class:
# vgg net : Rhodesian_ridgeback (n02087394) with probability 0.83
# res net : Rhodesian_ridgeback (n02087394) with probability 0.69
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_13_1.JPEG
# save heatmap_model_2 =>  n02090379_13_2.JPEG
# save heatmap_combine =>  n02090379_13_3.JPEG
# -------------------------------------------------------------
# Index: 81
# File name: n02090379_19.JPEG
# Predicted class:
# vgg net : Brabancon_griffon (n02112706) with probability 0.21
# res net : Rhodesian_ridgeback (n02087394) with probability 0.47
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_19_1.JPEG
# save heatmap_model_2 =>  n02090379_19_2.JPEG
# save heatmap_combine =>  n02090379_19_3.JPEG
# -------------------------------------------------------------
# Index: 82
# File name: n02090379_30.JPEG
# Predicted class:
# vgg net : redbone (n02090379) with probability 0.97
# res net : redbone (n02090379) with probability 0.51
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_30_1.JPEG
# save heatmap_model_2 =>  n02090379_30_2.JPEG
# save heatmap_combine =>  n02090379_30_3.JPEG
# -------------------------------------------------------------
# Index: 83
# File name: n02090379_4.JPEG
# Predicted class:
# vgg net : Chesapeake_Bay_retriever (n02099849) with probability 0.27
# res net : redbone (n02090379) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_4_1.JPEG
# save heatmap_model_2 =>  n02090379_4_2.JPEG
# save heatmap_combine =>  n02090379_4_3.JPEG
# -------------------------------------------------------------
# Index: 84
# File name: n02090379_55.JPEG
# Predicted class:
# vgg net : golden_retriever (n02099601) with probability 0.30
# res net : golden_retriever (n02099601) with probability 0.75
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_55_1.JPEG
# save heatmap_model_2 =>  n02090379_55_2.JPEG
# save heatmap_combine =>  n02090379_55_3.JPEG
# -------------------------------------------------------------
# Index: 85
# File name: n02090379_7.JPEG
# Predicted class:
# vgg net : redbone (n02090379) with probability 0.86
# res net : redbone (n02090379) with probability 0.85
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_7_1.JPEG
# save heatmap_model_2 =>  n02090379_7_2.JPEG
# save heatmap_combine =>  n02090379_7_3.JPEG
# -------------------------------------------------------------
# Index: 86
# File name: n02090379_73.JPEG
# Predicted class:
# vgg net : redbone (n02090379) with probability 1.00
# res net : redbone (n02090379) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_73_1.JPEG
# save heatmap_model_2 =>  n02090379_73_2.JPEG
# save heatmap_combine =>  n02090379_73_3.JPEG
# -------------------------------------------------------------
# Index: 87
# File name: n02090379_74.JPEG
# Predicted class:
# vgg net : redbone (n02090379) with probability 0.94
# res net : redbone (n02090379) with probability 0.84
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_74_1.JPEG
# save heatmap_model_2 =>  n02090379_74_2.JPEG
# save heatmap_combine =>  n02090379_74_3.JPEG
# -------------------------------------------------------------
# Index: 88
# File name: n02090379_78.JPEG
# Predicted class:
# vgg net : bloodhound (n02088466) with probability 0.61
# res net : bloodhound (n02088466) with probability 0.45
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_78_1.JPEG
# save heatmap_model_2 =>  n02090379_78_2.JPEG
# save heatmap_combine =>  n02090379_78_3.JPEG
# -------------------------------------------------------------
# Index: 89
# File name: n02090379_87.JPEG
# Predicted class:
# vgg net : redbone (n02090379) with probability 0.65
# res net : redbone (n02090379) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02090379_87_1.JPEG
# save heatmap_model_2 =>  n02090379_87_2.JPEG
# save heatmap_combine =>  n02090379_87_3.JPEG
# -------------------------------------------------------------
# Index: 90
# File name: n02091831_136.JPEG
# Predicted class:
# vgg net : black-and-tan_coonhound (n02089078) with probability 0.65
# res net : bluetick (n02088632) with probability 0.58
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_136_1.JPEG
# save heatmap_model_2 =>  n02091831_136_2.JPEG
# save heatmap_combine =>  n02091831_136_3.JPEG
# -------------------------------------------------------------
# Index: 91
# File name: n02091831_151.JPEG
# Predicted class:
# vgg net : ram (n02412080) with probability 0.45
# res net : white_wolf (n02114548) with probability 0.56
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_151_1.JPEG
# save heatmap_model_2 =>  n02091831_151_2.JPEG
# save heatmap_combine =>  n02091831_151_3.JPEG
# -------------------------------------------------------------
# Index: 92
# File name: n02091831_155.JPEG
# Predicted class:
# vgg net : Saluki (n02091831) with probability 0.99
# res net : Saluki (n02091831) with probability 0.87
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_155_1.JPEG
# save heatmap_model_2 =>  n02091831_155_2.JPEG
# save heatmap_combine =>  n02091831_155_3.JPEG
# -------------------------------------------------------------
# Index: 93
# File name: n02091831_213.JPEG
# Predicted class:
# vgg net : Irish_setter (n02100877) with probability 0.46
# res net : Irish_terrier (n02093991) with probability 0.41
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_213_1.JPEG
# save heatmap_model_2 =>  n02091831_213_2.JPEG
# save heatmap_combine =>  n02091831_213_3.JPEG
# -------------------------------------------------------------
# Index: 94
# File name: n02091831_31.JPEG
# Predicted class:
# vgg net : Saluki (n02091831) with probability 0.99
# res net : Saluki (n02091831) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_31_1.JPEG
# save heatmap_model_2 =>  n02091831_31_2.JPEG
# save heatmap_combine =>  n02091831_31_3.JPEG
# -------------------------------------------------------------
# Index: 95
# File name: n02091831_38.JPEG
# Predicted class:
# vgg net : Saluki (n02091831) with probability 0.98
# res net : Saluki (n02091831) with probability 0.95
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_38_1.JPEG
# save heatmap_model_2 =>  n02091831_38_2.JPEG
# save heatmap_combine =>  n02091831_38_3.JPEG
# -------------------------------------------------------------
# Index: 96
# File name: n02091831_55.JPEG
# Predicted class:
# vgg net : seat_belt (n04162706) with probability 0.25
# res net : Saluki (n02091831) with probability 0.53
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_55_1.JPEG
# save heatmap_model_2 =>  n02091831_55_2.JPEG
# save heatmap_combine =>  n02091831_55_3.JPEG
# -------------------------------------------------------------
# Index: 97
# File name: n02091831_90.JPEG
# Predicted class:
# vgg net : borzoi (n02090622) with probability 0.86
# res net : Saluki (n02091831) with probability 0.22
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_90_1.JPEG
# save heatmap_model_2 =>  n02091831_90_2.JPEG
# save heatmap_combine =>  n02091831_90_3.JPEG
# -------------------------------------------------------------
# Index: 98
# File name: n02091831_97.JPEG
# Predicted class:
# vgg net : Saluki (n02091831) with probability 0.97
# res net : English_setter (n02100735) with probability 0.41
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_97_1.JPEG
# save heatmap_model_2 =>  n02091831_97_2.JPEG
# save heatmap_combine =>  n02091831_97_3.JPEG
# -------------------------------------------------------------
# Index: 99
# File name: n02091831_99.JPEG
# Predicted class:
# vgg net : Saluki (n02091831) with probability 0.87
# res net : Saluki (n02091831) with probability 0.89
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02091831_99_1.JPEG
# save heatmap_model_2 =>  n02091831_99_2.JPEG
# save heatmap_combine =>  n02091831_99_3.JPEG
# -------------------------------------------------------------
# Index: 100
# File name: n02092339_14.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.94
# res net : Weimaraner (n02092339) with probability 0.92
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_14_1.JPEG
# save heatmap_model_2 =>  n02092339_14_2.JPEG
# save heatmap_combine =>  n02092339_14_3.JPEG
# -------------------------------------------------------------
# Index: 101
# File name: n02092339_16.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.99
# res net : Weimaraner (n02092339) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_16_1.JPEG
# save heatmap_model_2 =>  n02092339_16_2.JPEG
# save heatmap_combine =>  n02092339_16_3.JPEG
# -------------------------------------------------------------
# Index: 102
# File name: n02092339_31.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.55
# res net : Weimaraner (n02092339) with probability 0.95
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_31_1.JPEG
# save heatmap_model_2 =>  n02092339_31_2.JPEG
# save heatmap_combine =>  n02092339_31_3.JPEG
# -------------------------------------------------------------
# Index: 103
# File name: n02092339_38.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.71
# res net : Weimaraner (n02092339) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_38_1.JPEG
# save heatmap_model_2 =>  n02092339_38_2.JPEG
# save heatmap_combine =>  n02092339_38_3.JPEG
# -------------------------------------------------------------
# Index: 104
# File name: n02092339_40.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.47
# res net : vizsla (n02100583) with probability 0.74
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_40_1.JPEG
# save heatmap_model_2 =>  n02092339_40_2.JPEG
# save heatmap_combine =>  n02092339_40_3.JPEG
# -------------------------------------------------------------
# Index: 105
# File name: n02092339_49.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.92
# res net : Weimaraner (n02092339) with probability 0.74
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_49_1.JPEG
# save heatmap_model_2 =>  n02092339_49_2.JPEG
# save heatmap_combine =>  n02092339_49_3.JPEG
# -------------------------------------------------------------
# Index: 106
# File name: n02092339_52.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.98
# res net : Weimaraner (n02092339) with probability 0.97
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_52_1.JPEG
# save heatmap_model_2 =>  n02092339_52_2.JPEG
# save heatmap_combine =>  n02092339_52_3.JPEG
# -------------------------------------------------------------
# Index: 107
# File name: n02092339_6.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 0.99
# res net : Weimaraner (n02092339) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_6_1.JPEG
# save heatmap_model_2 =>  n02092339_6_2.JPEG
# save heatmap_combine =>  n02092339_6_3.JPEG
# -------------------------------------------------------------
# Index: 108
# File name: n02092339_65.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 1.00
# res net : Weimaraner (n02092339) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_65_1.JPEG
# save heatmap_model_2 =>  n02092339_65_2.JPEG
# save heatmap_combine =>  n02092339_65_3.JPEG
# -------------------------------------------------------------
# Index: 109
# File name: n02092339_9.JPEG
# Predicted class:
# vgg net : Weimaraner (n02092339) with probability 1.00
# res net : Weimaraner (n02092339) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02092339_9_1.JPEG
# save heatmap_model_2 =>  n02092339_9_2.JPEG
# save heatmap_combine =>  n02092339_9_3.JPEG
# -------------------------------------------------------------
# Index: 110
# File name: n02317335_132.JPEG
# Predicted class:
# vgg net : starfish (n02317335) with probability 1.00
# res net : starfish (n02317335) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02317335_132_1.JPEG
# save heatmap_model_2 =>  n02317335_132_2.JPEG
# save heatmap_combine =>  n02317335_132_3.JPEG
# -------------------------------------------------------------
# Index: 111
# File name: n02317335_152.JPEG
# Predicted class:
# vgg net : starfish (n02317335) with probability 0.89
# res net : starfish (n02317335) with probability 0.37
# -------------------------------------------------------------
# save heatmap_model_1 =>  n02317335_152_1.JPEG
# save heatmap_model_2 =>  n02317335_152_2.JPEG
# save heatmap_combine =>  n02317335_152_3.JPEG
# ...
# Index: 262
# File name: n03633091_239.JPEG
# Predicted class:
# vgg net : ladle (n03633091) with probability 0.50
# res net : ladle (n03633091) with probability 0.85
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_239_1.JPEG
# save heatmap_model_2 =>  n03633091_239_2.JPEG
# save heatmap_combine =>  n03633091_239_3.JPEG
# -------------------------------------------------------------
# Index: 263
# File name: n03633091_3.JPEG
# Predicted class:
# vgg net : wooden_spoon (n04597913) with probability 0.42
# res net : wooden_spoon (n04597913) with probability 0.70
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_3_1.JPEG
# save heatmap_model_2 =>  n03633091_3_2.JPEG
# save heatmap_combine =>  n03633091_3_3.JPEG
# -------------------------------------------------------------
# Index: 264
# File name: n03633091_434.JPEG
# Predicted class:
# vgg net : ladle (n03633091) with probability 0.51
# res net : ladle (n03633091) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_434_1.JPEG
# save heatmap_model_2 =>  n03633091_434_2.JPEG
# save heatmap_combine =>  n03633091_434_3.JPEG
# -------------------------------------------------------------
# Index: 265
# File name: n03633091_537.JPEG
# Predicted class:
# vgg net : pot (n03991062) with probability 0.42
# res net : acorn (n12267677) with probability 0.43
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_537_1.JPEG
# save heatmap_model_2 =>  n03633091_537_2.JPEG
# save heatmap_combine =>  n03633091_537_3.JPEG
# -------------------------------------------------------------
# Index: 266
# File name: n03633091_575.JPEG
# Predicted class:
# vgg net : vine_snake (n01739381) with probability 0.38
# res net : ladle (n03633091) with probability 0.36
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_575_1.JPEG
# save heatmap_model_2 =>  n03633091_575_2.JPEG
# save heatmap_combine =>  n03633091_575_3.JPEG
# -------------------------------------------------------------
# Index: 267
# File name: n03633091_663.JPEG
# Predicted class:
# vgg net : ladle (n03633091) with probability 0.95
# res net : ladle (n03633091) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_663_1.JPEG
# save heatmap_model_2 =>  n03633091_663_2.JPEG
# save heatmap_combine =>  n03633091_663_3.JPEG
# -------------------------------------------------------------
# Index: 268
# File name: n03633091_720.JPEG
# Predicted class:
# vgg net : mixing_bowl (n03775546) with probability 0.65
# res net : mixing_bowl (n03775546) with probability 0.23
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_720_1.JPEG
# save heatmap_model_2 =>  n03633091_720_2.JPEG
# save heatmap_combine =>  n03633091_720_3.JPEG
# -------------------------------------------------------------
# Index: 269
# File name: n03633091_971.JPEG
# Predicted class:
# vgg net : clog (n03047690) with probability 0.50
# res net : ladle (n03633091) with probability 0.87
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03633091_971_1.JPEG
# save heatmap_model_2 =>  n03633091_971_2.JPEG
# save heatmap_combine =>  n03633091_971_3.JPEG
# -------------------------------------------------------------
# Index: 270
# File name: n03804744_1.JPEG
# Predicted class:
# vgg net : candle (n02948072) with probability 0.48
# res net : nail (n03804744) with probability 0.91
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_1_1.JPEG
# save heatmap_model_2 =>  n03804744_1_2.JPEG
# save heatmap_combine =>  n03804744_1_3.JPEG
# -------------------------------------------------------------
# Index: 271
# File name: n03804744_129.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.98
# res net : nail (n03804744) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_129_1.JPEG
# save heatmap_model_2 =>  n03804744_129_2.JPEG
# save heatmap_combine =>  n03804744_129_3.JPEG
# -------------------------------------------------------------
# Index: 272
# File name: n03804744_201.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.68
# res net : nail (n03804744) with probability 0.89
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_201_1.JPEG
# save heatmap_model_2 =>  n03804744_201_2.JPEG
# save heatmap_combine =>  n03804744_201_3.JPEG
# -------------------------------------------------------------
# Index: 273
# File name: n03804744_205.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.47
# res net : nail (n03804744) with probability 0.86
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_205_1.JPEG
# save heatmap_model_2 =>  n03804744_205_2.JPEG
# save heatmap_combine =>  n03804744_205_3.JPEG
# -------------------------------------------------------------
# Index: 274
# File name: n03804744_215.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.83
# res net : nail (n03804744) with probability 0.94
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_215_1.JPEG
# save heatmap_model_2 =>  n03804744_215_2.JPEG
# save heatmap_combine =>  n03804744_215_3.JPEG
# -------------------------------------------------------------
# Index: 275
# File name: n03804744_242.JPEG
# Predicted class:
# vgg net : spotlight (n04286575) with probability 0.22
# res net : corkscrew (n03109150) with probability 0.29
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_242_1.JPEG
# save heatmap_model_2 =>  n03804744_242_2.JPEG
# save heatmap_combine =>  n03804744_242_3.JPEG
# -------------------------------------------------------------
# Index: 276
# File name: n03804744_30.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.95
# res net : nail (n03804744) with probability 0.97
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_30_1.JPEG
# save heatmap_model_2 =>  n03804744_30_2.JPEG
# save heatmap_combine =>  n03804744_30_3.JPEG
# -------------------------------------------------------------
# Index: 277
# File name: n03804744_417.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.99
# res net : nail (n03804744) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_417_1.JPEG
# save heatmap_model_2 =>  n03804744_417_2.JPEG
# save heatmap_combine =>  n03804744_417_3.JPEG
# -------------------------------------------------------------
# Index: 278
# File name: n03804744_434.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.97
# res net : nail (n03804744) with probability 0.98
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_434_1.JPEG
# save heatmap_model_2 =>  n03804744_434_2.JPEG
# save heatmap_combine =>  n03804744_434_3.JPEG
# -------------------------------------------------------------
# Index: 279
# File name: n03804744_92.JPEG
# Predicted class:
# vgg net : nail (n03804744) with probability 0.95
# res net : nail (n03804744) with probability 0.94
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03804744_92_1.JPEG
# save heatmap_model_2 =>  n03804744_92_2.JPEG
# save heatmap_combine =>  n03804744_92_3.JPEG
# -------------------------------------------------------------
# Index: 280
# File name: n03961711_2.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 0.84
# res net : plate_rack (n03961711) with probability 0.76
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_2_1.JPEG
# save heatmap_model_2 =>  n03961711_2_2.JPEG
# save heatmap_combine =>  n03961711_2_3.JPEG
# -------------------------------------------------------------
# Index: 281
# File name: n03961711_208.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 1.00
# res net : plate_rack (n03961711) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_208_1.JPEG
# save heatmap_model_2 =>  n03961711_208_2.JPEG
# save heatmap_combine =>  n03961711_208_3.JPEG
# -------------------------------------------------------------
# Index: 282
# File name: n03961711_35.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 0.99
# res net : plate_rack (n03961711) with probability 0.49
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_35_1.JPEG
# save heatmap_model_2 =>  n03961711_35_2.JPEG
# save heatmap_combine =>  n03961711_35_3.JPEG
# -------------------------------------------------------------
# Index: 283
# File name: n03961711_36.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 1.00
# res net : plate_rack (n03961711) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_36_1.JPEG
# save heatmap_model_2 =>  n03961711_36_2.JPEG
# save heatmap_combine =>  n03961711_36_3.JPEG
# -------------------------------------------------------------
# Index: 284
# File name: n03961711_49.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 0.96
# res net : plate_rack (n03961711) with probability 0.95
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_49_1.JPEG
# save heatmap_model_2 =>  n03961711_49_2.JPEG
# save heatmap_combine =>  n03961711_49_3.JPEG
# -------------------------------------------------------------
# Index: 285
# File name: n03961711_51.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 1.00
# res net : plate_rack (n03961711) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_51_1.JPEG
# save heatmap_model_2 =>  n03961711_51_2.JPEG
# save heatmap_combine =>  n03961711_51_3.JPEG
# -------------------------------------------------------------
# Index: 286
# File name: n03961711_64.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 1.00
# res net : plate_rack (n03961711) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_64_1.JPEG
# save heatmap_model_2 =>  n03961711_64_2.JPEG
# save heatmap_combine =>  n03961711_64_3.JPEG
# -------------------------------------------------------------
# Index: 287
# File name: n03961711_72.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 1.00
# res net : plate_rack (n03961711) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_72_1.JPEG
# save heatmap_model_2 =>  n03961711_72_2.JPEG
# save heatmap_combine =>  n03961711_72_3.JPEG
# -------------------------------------------------------------
# Index: 288
# File name: n03961711_8.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 0.99
# res net : plate_rack (n03961711) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_8_1.JPEG
# save heatmap_model_2 =>  n03961711_8_2.JPEG
# save heatmap_combine =>  n03961711_8_3.JPEG
# -------------------------------------------------------------
# Index: 289
# File name: n03961711_83.JPEG
# Predicted class:
# vgg net : plate_rack (n03961711) with probability 0.91
# res net : plate_rack (n03961711) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n03961711_83_1.JPEG
# save heatmap_model_2 =>  n03961711_83_2.JPEG
# save heatmap_combine =>  n03961711_83_3.JPEG
# -------------------------------------------------------------
# Index: 290
# File name: n04141076_1015.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 0.98
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_1015_1.JPEG
# save heatmap_model_2 =>  n04141076_1015_2.JPEG
# save heatmap_combine =>  n04141076_1015_3.JPEG
# -------------------------------------------------------------
# Index: 291
# File name: n04141076_1189.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 0.99
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_1189_1.JPEG
# save heatmap_model_2 =>  n04141076_1189_2.JPEG
# save heatmap_combine =>  n04141076_1189_3.JPEG
# -------------------------------------------------------------
# Index: 292
# File name: n04141076_1529.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 1.00
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_1529_1.JPEG
# save heatmap_model_2 =>  n04141076_1529_2.JPEG
# save heatmap_combine =>  n04141076_1529_3.JPEG
# -------------------------------------------------------------
# Index: 293
# File name: n04141076_220.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 1.00
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_220_1.JPEG
# save heatmap_model_2 =>  n04141076_220_2.JPEG
# save heatmap_combine =>  n04141076_220_3.JPEG
# -------------------------------------------------------------
# Index: 294
# File name: n04141076_3.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 0.99
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_3_1.JPEG
# save heatmap_model_2 =>  n04141076_3_2.JPEG
# save heatmap_combine =>  n04141076_3_3.JPEG
# -------------------------------------------------------------
# Index: 295
# File name: n04141076_424.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 0.97
# res net : sax (n04141076) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_424_1.JPEG
# save heatmap_model_2 =>  n04141076_424_2.JPEG
# save heatmap_combine =>  n04141076_424_3.JPEG
# -------------------------------------------------------------
# Index: 296
# File name: n04141076_478.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 1.00
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_478_1.JPEG
# save heatmap_model_2 =>  n04141076_478_2.JPEG
# save heatmap_combine =>  n04141076_478_3.JPEG
# -------------------------------------------------------------
# Index: 297
# File name: n04141076_536.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 0.92
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_536_1.JPEG
# save heatmap_model_2 =>  n04141076_536_2.JPEG
# save heatmap_combine =>  n04141076_536_3.JPEG
# -------------------------------------------------------------
# Index: 298
# File name: n04141076_728.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 0.64
# res net : sax (n04141076) with probability 0.99
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_728_1.JPEG
# save heatmap_model_2 =>  n04141076_728_2.JPEG
# save heatmap_combine =>  n04141076_728_3.JPEG
# -------------------------------------------------------------
# Index: 299
# File name: n04141076_891.JPEG
# Predicted class:
# vgg net : sax (n04141076) with probability 0.51
# res net : sax (n04141076) with probability 1.00
# -------------------------------------------------------------
# save heatmap_model_1 =>  n04141076_891_1.JPEG
# save heatmap_model_2 =>  n04141076_891_2.JPEG
# save heatmap_combine =>  n04141076_891_3.JPEG
# -------------------------------------------------------------

# %%
pic_name = os.listdir(pic_folder)
# store picture ID eg.n01685808_102 into pic_ID_list
pic_ID_list = []
# store picture label_ID eg.n01685808 into pic_label_ID_list
pic_label_ID_list = []
for i in range(len(pic_name)):
    temp = str.split(pic_name[i], '.')
    temp_1 = str.split(temp[0], '_')
    pic_ID_list.append(temp[0])
    pic_label_ID_list.append(temp_1[0])
#print(pic_ID_list)

# %%
label_list =  pd.read_csv("./list.txt",sep=' ',header = None)
label_value = label_list.values
ID = []
label_name = []
for i in range(30):
    ID.append(label_value[i][0])
    label_name.append(label_value[i][1])
label_dic = dict(zip(ID,label_name))
print("imageNet label dic shape:",label_value.shape)

pic_label_name_list = []
for i in range(len(pic_label_ID_list)):
    pic_label_name_list.append(label_dic[pic_label_ID_list[i]])
# Out:
# imageNet label dic shape: (30, 2)

# %%
# number of keys = 12
# picture_imageNet_ID = n01685808_165
# lable_ID = n01685808
# true_label = whiptail
# predict_lable_model_1 = default => 0
# predict_lable_model_2 = default => 0
# prop_model_1 = default => 0
# prop_model_2 = default => 0
# view_X = scatter x position(float)  default => 0
# view_Y = scatter y position(float)  default => 0
# model_1 heatmap ID
# model_2 heatmap ID
# combine heatmap ID


'''
predict_lable_model_1 = []
predict_lable_model_2 = []
prop_model_1 = []
prop_model_2 = []
test_sort = []
'''
# Out:
# '\npredict_lable_model_1 = []\npredict_lable_model_2 = []\nprop_model_1 = []\nprop_model_2 = []\ntest_sort = []\n'

# %%
keys = ['picture_imageNet_ID', 'lable_ID', 'true_label', 
        'predict_lable_model_1','prop_model_1',
        'predict_lable_model_2','prop_model_2',
        'view_X', 'view_Y',
        'model_1_heatmap_ID','model_2_heatmap_ID','combine_heatmap_ID']
# initial list setting, default value = 0

# T-SNE or UMap
view_X = np.zeros(300)
view_Y = np.zeros(300)

# keras data
#predict_lable_model_1 = np.zeros(300)
#prop_model_1 = np.zeros(300)
#predict_lable_model_2 = np.zeros(300)
#prop_model_2 = np.zeros(300)
#model_1_heatmap_ID = np.zeros(300)
#model_2_heatmap_ID = np.zeros(300)
#combine_heatmap_ID = np.zeros(300)


temp = []
temp_key = []
for i in range(300):
    
    temp_key.append(pic_ID_list[i])           # picture_imageNet_ID = n01685808_165
    temp_key.append(pic_label_ID_list[i])     # lable_ID = n01685808
    temp_key.append(pic_label_name_list[i])   # true_label = whiptail
    
    temp_key.append(predict_lable_model_1[i]) # predict_lable_model_1 = default => 0
    temp_key.append(prop_model_1[i])          # prop_model_1 = default => 0
    temp_key.append(predict_lable_model_2[i]) # predict_lable_model_2 = default => 0
    temp_key.append(prop_model_2[i])          # prop_model_2 = default => 0
    
    temp_key.append(view_X[i])                # view_X = scatter x position(float)  default => 0
    temp_key.append(view_Y[i])                # view_Y = scatter y position(float)  default => 0
    
    temp_key.append(model_1_heatmap_ID[i])    # model_1 heatmap ID
    temp_key.append(model_2_heatmap_ID[i])    # model_2 heatmap ID
    temp_key.append(combine_heatmap_ID[i])    # combine heatmap ID

    temp.append(temp_key)
    temp_key = []
    
list_json=[dict(zip(keys,item)) for item in temp]
str_json=json.dumps(list_json,indent=2, ensure_ascii=False)
filename = 'result_'+'version_1'+'.json'
fileObject = open(filename, 'w') 
fileObject.write(str_json) 
fileObject.close()

# %%
#print(temp)

# %%
pic_label_name_list
predict_lable_model_1
predict_lable_model_2
error_count = 0
for i in range(300):

    if pic_label_name_list[i] != predict_lable_model_1[i] or pic_label_name_list[i] != predict_lable_model_2[i]:
        error_count += 1
        print("true:", pic_label_name_list[i])
        print("P1:", predict_lable_model_1[i])
        print("P2:", predict_lable_model_2[i])
print(error_count)
# Out:
# true: whiptail
# P1: alligator_lizard
# P2: whiptail
# true: whiptail
# P1: whiptail
# P2: alligator_lizard
# true: whiptail
# P1: whiptail
# P2: agama
# true: whiptail
# P1: garter_snake
# P2: whiptail
# true: whiptail
# P1: alligator_lizard
# P2: alligator_lizard
# true: whiptail
# P1: alligator_lizard
# P2: whiptail
# true: whiptail
# P1: whiptail
# P2: banded_gecko
# true: hognose_snake
# P1: horned_viper
# P2: horned_viper
# true: hognose_snake
# P1: water_snake
# P2: diamondback
# true: hognose_snake
# P1: water_snake
# P2: water_snake
# true: hognose_snake
# P1: night_snake
# P2: ringneck_snake
# true: hognose_snake
# P1: horned_viper
# P2: horned_viper
# true: spiny_lobster
# P1: spiny_lobster
# P2: hermit_crab
# true: Shih-Tzu
# P1: Brabancon_griffon
# P2: Shih-Tzu
# true: Shih-Tzu
# P1: Maltese_dog
# P2: Shih-Tzu
# true: Shih-Tzu
# P1: soft-coated_wheaten_terrier
# P2: Lhasa
# true: Shih-Tzu
# P1: Lhasa
# P2: Shih-Tzu
# true: Shih-Tzu
# P1: Lhasa
# P2: Lhasa
# true: Shih-Tzu
# P1: affenpinscher
# P2: affenpinscher
# true: black-and-tan_coonhound
# P1: Gordon_setter
# P2: black-and-tan_coonhound
# true: black-and-tan_coonhound
# P1: Gordon_setter
# P2: black-and-tan_coonhound
# true: black-and-tan_coonhound
# P1: bloodhound
# P2: bloodhound
# true: black-and-tan_coonhound
# P1: boathouse
# P2: black-and-tan_coonhound
# true: black-and-tan_coonhound
# P1: Gordon_setter
# P2: Gordon_setter
# true: black-and-tan_coonhound
# P1: black-and-tan_coonhound
# P2: bloodhound
# true: Walker_hound
# P1: Walker_hound
# P2: basset
# true: Walker_hound
# P1: basset
# P2: basset
# true: Walker_hound
# P1: bluetick
# P2: Walker_hound
# true: Walker_hound
# P1: Walker_hound
# P2: beagle
# true: Walker_hound
# P1: Walker_hound
# P2: basset
# true: Walker_hound
# P1: beagle
# P2: Walker_hound
# true: redbone
# P1: Rhodesian_ridgeback
# P2: Rhodesian_ridgeback
# true: redbone
# P1: Brabancon_griffon
# P2: Rhodesian_ridgeback
# true: redbone
# P1: Chesapeake_Bay_retriever
# P2: redbone
# true: redbone
# P1: golden_retriever
# P2: golden_retriever
# true: redbone
# P1: bloodhound
# P2: bloodhound
# true: Saluki
# P1: black-and-tan_coonhound
# P2: bluetick
# true: Saluki
# P1: ram
# P2: white_wolf
# true: Saluki
# P1: Irish_setter
# P2: Irish_terrier
# true: Saluki
# P1: seat_belt
# P2: Saluki
# true: Saluki
# P1: borzoi
# P2: Saluki
# true: Saluki
# P1: Saluki
# P2: English_setter
# true: Weimaraner
# P1: Weimaraner
# P2: vizsla
# true: starfish
# P1: coral_fungus
# P2: starfish
# true: starfish
# P1: starfish
# P2: king_crab
# true: starfish
# P1: hermit_crab
# P2: stingray
# true: hare
# P1: marmot
# P2: marmot
# true: hare
# P1: wood_rabbit
# P2: wallaby
# true: hare
# P1: gazelle
# P2: gazelle
# true: hare
# P1: wood_rabbit
# P2: hare
# true: sorrel
# P1: dhole
# P2: sorrel
# true: hartebeest
# P1: impala
# P2: gazelle
# true: Arabian_camel
# P1: water_buffalo
# P2: Arabian_camel
# true: Arabian_camel
# P1: Arabian_camel
# P2: horse_cart
# true: Arabian_camel
# P1: Chihuahua
# P2: Arabian_camel
# true: patas
# P1: guenon
# P2: patas
# true: patas
# P1: spider_monkey
# P2: spider_monkey
# true: patas
# P1: patas
# P2: marmot
# true: colobus
# P1: colobus
# P2: birdhouse
# true: squirrel_monkey
# P1: squirrel_monkey
# P2: mongoose
# true: squirrel_monkey
# P1: weasel
# P2: squirrel_monkey
# true: squirrel_monkey
# P1: titi
# P2: squirrel_monkey
# true: bicycle-built-for-two
# P1: mountain_bike
# P2: bicycle-built-for-two
# true: bicycle-built-for-two
# P1: unicycle
# P2: bicycle-built-for-two
# true: canoe
# P1: canoe
# P2: paddle
# true: canoe
# P1: boathouse
# P2: boathouse
# true: canoe
# P1: fountain
# P2: canoe
# true: catamaran
# P1: seashore
# P2: reel
# true: catamaran
# P1: catamaran
# P2: trimaran
# true: catamaran
# P1: wreck
# P2: catamaran
# true: catamaran
# P1: trimaran
# P2: trimaran
# true: cowboy_hat
# P1: ox
# P2: cowboy_hat
# true: cowboy_hat
# P1: sombrero
# P2: cowboy_hat
# true: cowboy_hat
# P1: lab_coat
# P2: lab_coat
# true: desk
# P1: cash_machine
# P2: refrigerator
# true: desk
# P1: barber_chair
# P2: sewing_machine
# true: desk
# P1: desktop_computer
# P2: desk
# true: desk
# P1: web_site
# P2: web_site
# true: desk
# P1: dining_table
# P2: bookcase
# true: electric_fan
# P1: ashcan
# P2: barrel
# true: electric_fan
# P1: tape_player
# P2: electric_fan
# true: electric_fan
# P1: chain_saw
# P2: chain_saw
# true: electric_fan
# P1: stage
# P2: stage
# true: ladle
# P1: abacus
# P2: ladle
# true: ladle
# P1: wooden_spoon
# P2: wooden_spoon
# true: ladle
# P1: pot
# P2: acorn
# true: ladle
# P1: vine_snake
# P2: ladle
# true: ladle
# P1: mixing_bowl
# P2: mixing_bowl
# true: ladle
# P1: clog
# P2: ladle
# true: nail
# P1: candle
# P2: nail
# true: nail
# P1: spotlight
# P2: corkscrew
# 91

# %%
with open(filename,'r',encoding='utf8')as fp:
    json_data = json.load(fp)
print(json_data[1])
print(json_data[0]['picture_imageNet_ID'])
# Out:
# {'picture_imageNet_ID': 'n01685808_123', 'lable_ID': 'n01685808', 'true_label': 'whiptail', 'predict_lable_model_1': 'whiptail', 'prop_model_1': '0.78816617', 'predict_lable_model_2': 'alligator_lizard', 'prop_model_2': '0.8267158', 'view_X': 0.0, 'view_Y': 0.0, 'model_1_heatmap_ID': 'n01685808_123_1', 'model_2_heatmap_ID': 'n01685808_123_2', 'combine_heatmap_ID': 'n01685808_123_3'}
# n01685808_102

# %%
'''
for i in range(300):
    if test_sort[i] == pic_ID_list[i]:
        print("success")
    else:
        print("failed")
'''
